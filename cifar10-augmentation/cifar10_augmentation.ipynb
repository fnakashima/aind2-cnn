# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN on augmented images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
y_valid = keras.utils.to_categorical(y_valid, num_classes)

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Create and Configure Augmented Image Generator

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# create and configure augmented image generator
datagen_valid = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# fit augmented image generator on data
datagen_train.fit(x_train)
datagen_valid.fit(x_valid)

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    #rotation_range=10.,
    #width_shift_range=0.1,
    #height_shift_range=0.1,
    #shear_range=0.2,
    #zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest')

# create and configure augmented image generator
datagen_valid = ImageDataGenerator(
    #rotation_range=10.,
    #width_shift_range=0.1,
    #height_shift_range=0.1,
    #shear_range=0.2,
    #zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest')

# fit augmented image generator on data
datagen_train.fit(x_train)
#datagen_valid.fit(x_valid)

# %% [markdown]
# ### 6. Visualize Original and Augmented Images

# %%
import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen_train.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;

# %% [markdown]
# ### 7. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 8. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 9. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

batch_size = 32
epochs = 50

# train the model
checkpointer = ModelCheckpoint(filepath='aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(datagen_train.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=epochs, verbose=2, callbacks=[checkpointer],
                    validation_data=datagen_valid.flow(x_valid, y_valid, batch_size=batch_size),
                    validation_steps=x_valid.shape[0] // batch_size)
# Out:
# Epoch 1/50
# Epoch 00000: val_loss improved from inf to 1.31417, saving model to aug_model.weights.best.hdf5
# 17s - loss: 1.5923 - acc: 0.4236 - val_loss: 1.3142 - val_acc: 0.5256
# Epoch 2/50
# Epoch 00001: val_loss improved from 1.31417 to 1.13835, saving model to aug_model.weights.best.hdf5
# 12s - loss: 1.3013 - acc: 0.5325 - val_loss: 1.1383 - val_acc: 0.5912
# Epoch 3/50
# Epoch 00002: val_loss improved from 1.13835 to 1.06038, saving model to aug_model.weights.best.hdf5
# 12s - loss: 1.1923 - acc: 0.5785 - val_loss: 1.0604 - val_acc: 0.6290
# Epoch 4/50
# Epoch 00003: val_loss improved from 1.06038 to 1.00887, saving model to aug_model.weights.best.hdf5
# 12s - loss: 1.1249 - acc: 0.6034 - val_loss: 1.0089 - val_acc: 0.6437
# Epoch 5/50
# Epoch 00004: val_loss improved from 1.00887 to 0.99406, saving model to aug_model.weights.best.hdf5
# 12s - loss: 1.0834 - acc: 0.6236 - val_loss: 0.9941 - val_acc: 0.6546
# Epoch 6/50
# Epoch 00005: val_loss did not improve
# 11s - loss: 1.0613 - acc: 0.6323 - val_loss: 1.0286 - val_acc: 0.6594
# Epoch 7/50
# Epoch 00006: val_loss improved from 0.99406 to 0.92394, saving model to aug_model.weights.best.hdf5
# 12s - loss: 1.0493 - acc: 0.6352 - val_loss: 0.9239 - val_acc: 0.6789
# Epoch 8/50
# Epoch 00007: val_loss did not improve
# 11s - loss: 1.0455 - acc: 0.6433 - val_loss: 0.9448 - val_acc: 0.6741
# Epoch 9/50
# Epoch 00008: val_loss improved from 0.92394 to 0.90581, saving model to aug_model.weights.best.hdf5
# 11s - loss: 1.0417 - acc: 0.6459 - val_loss: 0.9058 - val_acc: 0.6832
# Epoch 10/50
# Epoch 00009: val_loss did not improve
# 11s - loss: 1.0358 - acc: 0.6487 - val_loss: 0.9397 - val_acc: 0.6876
# Epoch 11/50
# Epoch 00010: val_loss did not improve
# 11s - loss: 1.0423 - acc: 0.6452 - val_loss: 0.9571 - val_acc: 0.6773
# Epoch 12/50
# Epoch 00011: val_loss did not improve
# 11s - loss: 1.0565 - acc: 0.6427 - val_loss: 0.9567 - val_acc: 0.6848
# Epoch 13/50
# Epoch 00012: val_loss did not improve
# 11s - loss: 1.0761 - acc: 0.6387 - val_loss: 1.0684 - val_acc: 0.6622
# Epoch 14/50
# Epoch 00013: val_loss did not improve
# 11s - loss: 1.0945 - acc: 0.6338 - val_loss: 1.0164 - val_acc: 0.6600
# Epoch 15/50
# Epoch 00014: val_loss did not improve
# 11s - loss: 1.1090 - acc: 0.6316 - val_loss: 0.9570 - val_acc: 0.6745
# Epoch 16/50
# Epoch 00015: val_loss did not improve
# 11s - loss: 1.1243 - acc: 0.6251 - val_loss: 1.0031 - val_acc: 0.6630
# Epoch 17/50
# Epoch 00016: val_loss did not improve
# 11s - loss: 1.1391 - acc: 0.6189 - val_loss: 0.9956 - val_acc: 0.6677
# Epoch 18/50
# Epoch 00017: val_loss did not improve
# 11s - loss: 1.1623 - acc: 0.6127 - val_loss: 1.0564 - val_acc: 0.6556
# Epoch 19/50
# Epoch 00018: val_loss did not improve
# 11s - loss: 1.1788 - acc: 0.6060 - val_loss: 1.1691 - val_acc: 0.6182
# Epoch 20/50
# Epoch 00019: val_loss did not improve
# 11s - loss: 1.1860 - acc: 0.6050 - val_loss: 1.0649 - val_acc: 0.6588
# Epoch 21/50
# Epoch 00020: val_loss did not improve
# 11s - loss: 1.2025 - acc: 0.6027 - val_loss: 1.1054 - val_acc: 0.6341
# Epoch 22/50
# Epoch 00021: val_loss did not improve
# 11s - loss: 1.2228 - acc: 0.5936 - val_loss: 0.9823 - val_acc: 0.6806
# Epoch 23/50
# Epoch 00022: val_loss did not improve
# 11s - loss: 1.2385 - acc: 0.5948 - val_loss: 1.0976 - val_acc: 0.6467
# Epoch 24/50
# Epoch 00023: val_loss did not improve
# 11s - loss: 1.2494 - acc: 0.5885 - val_loss: 1.0677 - val_acc: 0.6296
# Epoch 25/50
# Epoch 00024: val_loss did not improve
# 11s - loss: 1.2459 - acc: 0.5849 - val_loss: 1.3011 - val_acc: 0.5771
# Epoch 26/50
# Epoch 00025: val_loss did not improve
# 11s - loss: 1.2759 - acc: 0.5751 - val_loss: 1.1375 - val_acc: 0.5992
# Epoch 27/50
# Epoch 00026: val_loss did not improve
# 11s - loss: 1.2924 - acc: 0.5713 - val_loss: 1.2086 - val_acc: 0.5791
# Epoch 28/50
# Epoch 00027: val_loss did not improve
# 11s - loss: 1.3139 - acc: 0.5638 - val_loss: 1.1068 - val_acc: 0.6397
# Epoch 29/50
# Epoch 00028: val_loss did not improve
# 11s - loss: 1.3181 - acc: 0.5632 - val_loss: 1.0520 - val_acc: 0.6457
# Epoch 30/50
# Epoch 00029: val_loss did not improve
# 11s - loss: 1.3338 - acc: 0.5579 - val_loss: 1.2327 - val_acc: 0.5851
# Epoch 31/50
# Epoch 00030: val_loss did not improve
# 11s - loss: 1.3598 - acc: 0.5523 - val_loss: 1.3155 - val_acc: 0.5519
# Epoch 32/50
# Epoch 00031: val_loss did not improve
# 11s - loss: 1.3544 - acc: 0.5513 - val_loss: 1.2246 - val_acc: 0.5948
# Epoch 33/50
# Epoch 00032: val_loss did not improve
# 11s - loss: 1.3580 - acc: 0.5512 - val_loss: 1.1644 - val_acc: 0.6081
# Epoch 34/50
# Epoch 00033: val_loss did not improve
# 11s - loss: 1.3752 - acc: 0.5449 - val_loss: 1.1311 - val_acc: 0.6174
# Epoch 35/50
# Epoch 00034: val_loss did not improve
# 11s - loss: 1.3878 - acc: 0.5418 - val_loss: 1.2892 - val_acc: 0.5628
# Epoch 36/50
# Epoch 00035: val_loss did not improve
# 11s - loss: 1.3875 - acc: 0.5415 - val_loss: 1.2635 - val_acc: 0.5566
# Epoch 37/50
# Epoch 00036: val_loss did not improve
# 11s - loss: 1.4214 - acc: 0.5264 - val_loss: 1.0699 - val_acc: 0.6504
# Epoch 38/50
# Epoch 00037: val_loss did not improve
# 11s - loss: 1.4225 - acc: 0.5243 - val_loss: 1.2011 - val_acc: 0.6072
# Epoch 39/50
# Epoch 00038: val_loss did not improve
# 11s - loss: 1.4322 - acc: 0.5251 - val_loss: 1.2651 - val_acc: 0.5529
# Epoch 40/50
# Epoch 00039: val_loss did not improve
# 11s - loss: 1.4296 - acc: 0.5242 - val_loss: 1.0976 - val_acc: 0.6204
# Epoch 41/50
# Epoch 00040: val_loss did not improve
# 11s - loss: 1.4460 - acc: 0.5196 - val_loss: 1.3032 - val_acc: 0.5642
# Epoch 42/50
# Epoch 00041: val_loss did not improve
# 11s - loss: 1.4633 - acc: 0.5083 - val_loss: 1.2597 - val_acc: 0.5803
# Epoch 43/50
# Epoch 00042: val_loss did not improve
# 11s - loss: 1.4728 - acc: 0.5091 - val_loss: 1.4352 - val_acc: 0.4974
# Epoch 44/50
# Epoch 00043: val_loss did not improve
# 11s - loss: 1.4837 - acc: 0.5060 - val_loss: 1.2864 - val_acc: 0.5503
# Epoch 45/50
# Epoch 00044: val_loss did not improve
# 11s - loss: 1.4812 - acc: 0.5053 - val_loss: 1.2704 - val_acc: 0.5439
# Epoch 46/50
# Epoch 00045: val_loss did not improve
# 11s - loss: 1.4675 - acc: 0.5066 - val_loss: 1.3288 - val_acc: 0.5203
# Epoch 47/50
# Epoch 00046: val_loss did not improve
# 11s - loss: 1.4859 - acc: 0.5034 - val_loss: 1.3229 - val_acc: 0.5515
# Epoch 48/50
# Epoch 00047: val_loss did not improve
# 11s - loss: 1.5154 - acc: 0.4919 - val_loss: 1.2260 - val_acc: 0.5731
# Epoch 49/50
# Epoch 00048: val_loss did not improve
# 11s - loss: 1.4977 - acc: 0.4942 - val_loss: 1.2995 - val_acc: 0.5397
# Epoch 50/50
# Epoch 00049: val_loss did not improve
# 11s - loss: 1.5165 - acc: 0.4906 - val_loss: 1.1914 - val_acc: 0.5827

# %% [markdown]
# ### 10. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('aug_model.weights.best.hdf5')

# %% [markdown]
# ### 11. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.676
